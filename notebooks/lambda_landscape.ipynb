# %%
from pathlib import Path
import sys

project_root = Path("../").resolve()
sys.path.insert(0, str(project_root))

# %%
from visuals.lambda_landscape import plot_lambda_vs_wolfram_rules

# %%
plot_lambda_vs_wolfram_rules()
