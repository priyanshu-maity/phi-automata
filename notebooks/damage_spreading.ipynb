# %%
from pathlib import Path
import sys

project_root = Path("../").resolve()
sys.path.insert(0, str(project_root))

# %%
from metrics.damage_spreading import compute_damage_spreading_curve
from visuals.damage_spreading import plot_damage_spreading_curve

# %%
damage_spreading_curve = compute_damage_spreading_curve(
    rule=30,
    width=101,
    steps=200,
    trials=500
)

plot_damage_spreading_curve(damage_spreading_curve, rule=30)

# %%
damage_spreading_curve = compute_damage_spreading_curve(
    rule=90,
    width=101,
    steps=200,
    trials=500
)

plot_damage_spreading_curve(damage_spreading_curve, rule=90)

# %%
damage_spreading_curve = compute_damage_spreading_curve(
    rule=110,
    width=101,
    steps=200,
    trials=500
)

plot_damage_spreading_curve(damage_spreading_curve, rule=110)
