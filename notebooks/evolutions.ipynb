# %%
from pathlib import Path
import sys

project_root = Path("../").resolve()
sys.path.insert(0, str(project_root))

# %%
from automata.elementary import ElementaryCA
from visuals.evolutions import plot_evolution

# %%
eca = ElementaryCA(rule=30, boundary='fixed')
history = eca.run(width=101, steps=50, seed='single')
plot_evolution(history, title=f'Rule 30 Evolution  |  fixed boundary  |  λ = {eca.lambda_:.3f}')

# %%
eca = ElementaryCA(rule=90, boundary='fixed')
history = eca.run(width=101, steps=50, seed='single')
plot_evolution(history, title=f'Rule 90 Evolution  |  fixed boundary  |  λ = {eca.lambda_:.3f}')

# %%
eca = ElementaryCA(rule=110, boundary='fixed')
history = eca.run(width=101, steps=50, seed='single')
plot_evolution(history, title=f'Rule 110 Evolution  |  fixed boundary  |  λ = {eca.lambda_:.3f}')
